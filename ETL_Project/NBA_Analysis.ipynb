# %% [markdown]
# # ETL Project
# ##    Team Baldies
# ###                   Keith Ross
# ###                 Jordan Whitney
# ###                  Brian Ross
# # Extract
# ## - Data Sets
# ##        -Website scraping/extraction
# ###             - Player Salaries from http://www.espn.com/nba/salaries/
# ###             - Player Stats from https://www.nba.com
# # Transform
# ### - Consistant formatting
#
# # Load
# ## - MongosDB

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
from urllib.request import urlopen
import pymongo
from pymongo import MongoClient
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import plotly.plotly as py
import plotly.graph_objs as go

# %%
url = 'http://www.espn.com/nba/salaries' 

html = urlopen(url)

# %%
soup = BeautifulSoup(html)

# %%
soup.findAll('tr',limit=4)[1].findAll('td')
# Out:
# [<td>1</td>,
#  <td><a href="http://www.espn.com/nba/player/_/id/3975/stephen-curry">Stephen Curry</a>, PG</td>,
#  <td><a href="http://www.espn.com/nba/team/_/name/gs/golden-state-warriors">Golden State Warriors</a></td>,
#  <td style="text-align:right;">$37,457,154</td>]

# %%
column_headers = [th.getText() for th in soup.findAll('tr', limit=2)[1].findAll('td')]

# %%
column_headers
# Out:
# ['1', 'Stephen Curry, PG', 'Golden State Warriors', '$37,457,154']

# %%
data_rows = soup.findAll('tr')[1:]

# %%
player_data = [[td.getText() for td in data_rows[i].findAll('td')]
              for i in range(len(data_rows))]

# %%
player_data_02 = []
for i in range(len(data_rows)):
    player_row = []
    for td in data_rows[i].findAll('td'):
        player_row.append(td.getText())
        
    player_data_02.append(player_row)

# %%
player_data == player_data_02
# Out:
# True

# %% [markdown]
# # Transform
# ### - Consistant formatting
# ### - http://www.espn.com/nba/salaries

# %%
nba_salary_df = pd.DataFrame(player_data, columns=column_headers)
nba_salary_df.head()
# Out:
#    1      Stephen Curry, PG  Golden State Warriors  $37,457,154
# 0  1      Stephen Curry, PG  Golden State Warriors  $37,457,154
# 1  2  Russell Westbrook, PG  Oklahoma City Thunder  $35,654,150
# 2  3         Chris Paul, PG        Houston Rockets  $35,654,150
# 3  4      Blake Griffin, PF        Detroit Pistons  $32,088,932
# 4  5     Gordon Hayward, SF         Boston Celtics  $31,214,295

# %%
nba_salary_df = pd.DataFrame(player_data, columns=column_headers)
nba_salary_df.columns = ['Index','Name', 'Team','Salary']
del nba_salary_df['Index']
del nba_salary_df['Team']
nba_salary_df_revised = nba_salary_df['Name'].str.split(',', n = 1, expand = True)
del nba_salary_df_revised[1]
merged_nba_salary_df = nba_salary_df.merge(nba_salary_df_revised, how='outer', left_index = True, right_index = True)
merged_nba_salary_df.columns = ['name','Salary','Name']
del merged_nba_salary_df['name']
merged_nba_salary_df = merged_nba_salary_df[['Name','Salary']]
merged_nba_salary_df.head()
# Out:
#                 Name       Salary
# 0      Stephen Curry  $37,457,154
# 1  Russell Westbrook  $35,654,150
# 2         Chris Paul  $35,654,150
# 3      Blake Griffin  $32,088,932
# 4     Gordon Hayward  $31,214,295

# %% [markdown]
# ##             - Player Stats from https://www.nba.com

# %%
nba_player_stats = pd.read_csv('./NBA_player_stats.csv')
nba_player_stats.head()
# Out:
#    #                 PLAYER  GP   MIN   PTS   FGM   FGA   FG%  3PM   3PA  \
# 0  1           James Harden  78  36.8  36.1  10.8  24.5  44.2  4.8  13.2
# 1  2            Paul George  77  36.9  28.0   9.2  21.0  43.8  3.8   9.8
# 2  3  Giannis Antetokounmpo  72  32.8  27.7  10.0  17.3  57.8  0.7   2.8
# 3  4            Joel Embiid  64  33.7  27.5   9.1  18.7  48.4  1.2   4.1
# 4  5          Stephen Curry  69  33.8  27.3   9.2  19.4  47.2  5.1  11.7
#
#    ...    FTA   FT%  OREB  DREB   REB  AST  STL  BLK  TOV   EFF
# 0  ...   11.0  87.9   0.8   5.8   6.6  7.5  2.0  0.7  5.0  33.1
# 1  ...    7.0  83.9   1.4   6.8   8.2  4.1  2.2  0.4  2.7  27.4
# 2  ...    9.5  72.9   2.2  10.3  12.5  5.9  1.3  1.5  3.7  35.3
# 3  ...   10.1  80.4   2.5  11.1  13.6  3.7  0.7  1.9  3.5  32.2
# 4  ...    4.2  91.6   0.7   4.7   5.3  5.2  1.3  0.4  2.8  26.1
#
# [5 rows x 22 columns]

# %%
nba_player_stats_df = pd.DataFrame(nba_player_stats)
nba_player_stats_df = nba_player_stats_df.drop(['#'], axis=1)
nba_player_stats_df = nba_player_stats_df.rename(columns={'PLAYER':'Name'})
nba_player_stats_df.head()
# Out:
#                     Name  GP   MIN   PTS   FGM   FGA   FG%  3PM   3PA   3P%  \
# 0           James Harden  78  36.8  36.1  10.8  24.5  44.2  4.8  13.2  36.8
# 1            Paul George  77  36.9  28.0   9.2  21.0  43.8  3.8   9.8  38.6
# 2  Giannis Antetokounmpo  72  32.8  27.7  10.0  17.3  57.8  0.7   2.8  25.6
# 3            Joel Embiid  64  33.7  27.5   9.1  18.7  48.4  1.2   4.1  30.0
# 4          Stephen Curry  69  33.8  27.3   9.2  19.4  47.2  5.1  11.7  43.7
#
#    ...    FTA   FT%  OREB  DREB   REB  AST  STL  BLK  TOV   EFF
# 0  ...   11.0  87.9   0.8   5.8   6.6  7.5  2.0  0.7  5.0  33.1
# 1  ...    7.0  83.9   1.4   6.8   8.2  4.1  2.2  0.4  2.7  27.4
# 2  ...    9.5  72.9   2.2  10.3  12.5  5.9  1.3  1.5  3.7  35.3
# 3  ...   10.1  80.4   2.5  11.1  13.6  3.7  0.7  1.9  3.5  32.2
# 4  ...    4.2  91.6   0.7   4.7   5.3  5.2  1.3  0.4  2.8  26.1
#
# [5 rows x 21 columns]

# %% [markdown]
# ## - Merge 2 dataframes

# %%
merged_nba_analysis_df = merged_nba_salary_df.merge(nba_player_stats_df, how='outer', on = ['Name'])
merged_nba_analysis_df = merged_nba_analysis_df.dropna()
merged_nba_analysis_df = merged_nba_analysis_df.reset_index(drop=True)
merged_nba_analysis_df = merged_nba_analysis_df.set_index('Name')
merged_nba_analysis_df = merged_nba_analysis_df.sort_values('Salary', ascending = True)
merged_nba_analysis_df.head()
# Out:
#                         Salary    GP   MIN   PTS  FGM   FGA   FG%  3PM  3PA  \
# Name
# Jimmy Butler       $20,445,779  65.0  33.6  18.7  6.4  13.9  46.2  1.0  3.0
# Danilo Gallinari   $21,587,579  68.0  30.3  19.8  6.0  13.0  46.3  2.4  5.5
# Aaron Gordon       $21,590,909  78.0  33.8  16.0  6.0  13.4  44.9  1.6  4.4
# Serge Ibaka        $21,666,667  74.0  27.2  15.0  6.3  11.9  52.9  0.7  2.3
# LaMarcus Aldridge  $22,347,015  81.0  33.2  21.3  8.4  16.3  51.9  0.1  0.5
#
#                     3P%  ...   FTA   FT%  OREB  DREB  REB  AST  STL  BLK  TOV  \
# Name                     ...
# Jimmy Butler       34.7  ...   5.6  85.5   1.9   3.4  5.3  4.0  1.9  0.6  1.5
# Danilo Gallinari   43.3  ...   6.0  90.4   0.8   5.3  6.1  2.6  0.7  0.3  1.5
# Aaron Gordon       34.9  ...   3.2  73.1   1.7   5.7  7.4  3.7  0.7  0.7  2.1
# Serge Ibaka        29.0  ...   2.4  76.3   2.1   6.0  8.1  1.3  0.4  1.4  1.5
# LaMarcus Aldridge  23.8  ...   5.1  84.7   3.1   6.1  9.2  2.4  0.5  1.3  1.8
#
#                     EFF
# Name
# Jimmy Butler       20.7
# Danilo Gallinari   20.6
# Aaron Gordon       18.2
# Serge Ibaka        18.6
# LaMarcus Aldridge  24.4
#
# [5 rows x 21 columns]

# %% [markdown]
# # Load
# ## - MongosDB

# %%
data_dict = merged_nba_analysis_df.to_dict()

# %%
data_dict
# Out:
# {'Salary': {'Jimmy Butler': '$20,445,779',
#   'Danilo Gallinari': '$21,587,579',
#   'Aaron Gordon': '$21,590,909',
#   'Serge Ibaka': '$21,666,667',
#   'LaMarcus Aldridge': '$22,347,015',
#   'DeAndre Jordan': '$22,897,200',
#   'Kawhi Leonard': '$23,114,067',
#   'Rudy Gobert': '$23,241,573',
#   'Nicolas Batum': '$24,000,000',
#   'Harrison Barnes': '$24,107,258',
#   'Marc Gasol': '$24,119,025',
#   'Giannis Antetokounmpo': '$24,157,303',
#   'Steven Adams': '$24,157,303',
#   'Nikola Jokic': '$24,605,181',
#   'Hassan Whiteside': '$25,434,262',
#   'Bradley Beal': '$25,434,263',
#   'Andrew Wiggins': '$25,467,250',
#   'Joel Embiid': '$25,467,250',
#   'CJ McCollum': '$25,759,766',
#   'Jrue Holiday': '$25,976,111',
#   'DeMar DeRozan': '$27,739,975',
#   'Damian Lillard': '$27,977,689',
#   'Al Horford': '$28,928,709',
#   'Paul Millsap': '$29,230,769',
#   'Kevin Durant': '$30,000,000',
#   'James Harden': '$30,421,854',
#   'Mike Conley': '$30,521,115',
#   'Paul George': '$30,560,700',
#   'Kyle Lowry': '$31,200,000',
#   'Gordon Hayward': '$31,214,295',
#   'Blake Griffin': '$32,088,932',
#   'Chris Paul': '$35,654,150',
#   'Russell Westbrook': '$35,654,150',
#   'Stephen Curry': '$37,457,154'},
#  'GP': {'Jimmy Butler': 65.0,
#   'Danilo Gallinari': 68.0,
#   'Aaron Gordon': 78.0,
#   'Serge Ibaka': 74.0,
#   'LaMarcus Aldridge': 81.0,
#   'DeAndre Jordan': 69.0,
#   'Kawhi Leonard': 60.0,
#   'Rudy Gobert': 81.0,
#   'Nicolas Batum': 75.0,
#   'Harrison Barnes': 77.0,
#   'Marc Gasol': 79.0,
#   'Giannis Antetokounmpo': 72.0,
#   'Steven Adams': 80.0,
#   'Nikola Jokic': 80.0,
#   'Hassan Whiteside': 72.0,
#   'Bradley Beal': 82.0,
#   'Andrew Wiggins': 73.0,
#   'Joel Embiid': 64.0,
#   'CJ McCollum': 70.0,
#   'Jrue Holiday': 67.0,
#   'DeMar DeRozan': 77.0,
#   'Damian Lillard': 80.0,
#   'Al Horford': 68.0,
#   'Paul Millsap': 70.0,
#   'Kevin Durant': 78.0,
#   'James Harden': 78.0,
#   'Mike Conley': 70.0,
#   'Paul George': 77.0,
#   'Kyle Lowry': 65.0,
#   'Gordon Hayward': 72.0,
#   'Blake Griffin': 75.0,
#   'Chris Paul': 58.0,
#   'Russell Westbrook': 73.0,
#   'Stephen Curry': 69.0},
#  'MIN': {'Jimmy Butler': 33.6,
#   'Danilo Gallinari': 30.3,
#   'Aaron Gordon': 33.8,
#   'Serge Ibaka': 27.2,
#   'LaMarcus Aldridge': 33.2,
#   'DeAndre Jordan': 29.7,
#   'Kawhi Leonard': 34.0,
#   'Rudy Gobert': 31.8,
#   'Nicolas Batum': 31.4,
#   'Harrison Barnes': 32.9,
#   'Marc Gasol': 30.8,
#   'Giannis Antetokounmpo': 32.8,
#   'Steven Adams': 33.4,
#   'Nikola Jokic': 31.3,
#   'Hassan Whiteside': 23.3,
#   'Bradley Beal': 36.9,
#   'Andrew Wiggins': 34.8,
#   'Joel Embiid': 33.7,
#   'CJ McCollum': 33.9,
#   'Jrue Holiday': 35.9,
#   'DeMar DeRozan': 34.9,
#   'Damian Lillard': 35.5,
#   'Al Horford': 29.0,
#   'Paul Millsap': 27.1,
#   'Kevin Durant': 34.6,
#   'James Harden': 36.8,
#   'Mike Conley': 33.5,
#   'Paul George': 36.9,
#   'Kyle Lowry': 34.0,
#   'Gordon Hayward': 25.9,
#   'Blake Griffin': 35.0,
#   'Chris Paul': 32.0,
#   'Russell Westbrook': 36.0,
#   'Stephen Curry': 33.8},
#  'PTS': {'Jimmy Butler': 18.7,
#   'Danilo Gallinari': 19.8,
#   'Aaron Gordon': 16.0,
#   'Serge Ibaka': 15.0,
#   'LaMarcus Aldridge': 21.3,
#   'DeAndre Jordan': 11.0,
#   'Kawhi Leonard': 26.6,
#   'Rudy Gobert': 15.9,
#   'Nicolas Batum': 9.3,
#   'Harrison Barnes': 16.4,
#   'Marc Gasol': 13.6,
#   'Giannis Antetokounmpo': 27.7,
#   'Steven Adams': 13.9,
#   'Nikola Jokic': 20.1,
#   'Hassan Whiteside': 12.3,
#   'Bradley Beal': 25.6,
#   'Andrew Wiggins': 18.1,
#   'Joel Embiid': 27.5,
#   'CJ McCollum': 21.0,
#   'Jrue Holiday': 21.2,
#   'DeMar DeRozan': 21.2,
#   'Damian Lillard': 25.8,
#   'Al Horford': 13.6,
#   'Paul Millsap': 12.6,
#   'Kevin Durant': 26.0,
#   'James Harden': 36.1,
#   'Mike Conley': 21.1,
#   'Paul George': 28.0,
#   'Kyle Lowry': 14.2,
#   'Gordon Hayward': 11.5,
#   'Blake Griffin': 24.5,
#   'Chris Paul': 15.6,
#   'Russell Westbrook': 22.9,
#   'Stephen Curry': 27.3},
#  'FGM': {'Jimmy Butler': 6.4,
#   'Danilo Gallinari': 6.0,
#   'Aaron Gordon': 6.0,
#   'Serge Ibaka': 6.3,
#   'LaMarcus Aldridge': 8.4,
#   'DeAndre Jordan': 4.1,
#   'Kawhi Leonard': 9.3,
#   'Rudy Gobert': 5.9,
#   'Nicolas Batum': 3.4,
#   'Harrison Barnes': 5.6,
#   'Marc Gasol': 4.9,
#   'Giannis Antetokounmpo': 10.0,
#   'Steven Adams': 6.0,
#   'Nikola Jokic': 7.7,
#   'Hassan Whiteside': 5.4,
#   'Bradley Beal': 9.3,
#   'Andrew Wiggins': 6.8,
#   'Joel Embiid': 9.1,
#   'CJ McCollum': 8.2,
#   'Jrue Holiday': 8.2,
#   'DeMar DeRozan': 8.2,
#   'Damian Lillard': 8.5,
#   'Al Horford': 5.7,
#   'Paul Millsap': 4.6,
#   'Kevin Durant': 9.2,
#   'James Harden': 10.8,
#   'Mike Conley': 7.0,
#   'Paul George': 9.2,
#   'Kyle Lowry': 4.7,
#   'Gordon Hayward': 4.1,
#   'Blake Griffin': 8.3,
#   'Chris Paul': 5.2,
#   'Russell Westbrook': 8.6,
#   'Stephen Curry': 9.2},
#  'FGA': {'Jimmy Butler': 13.9,
#   'Danilo Gallinari': 13.0,
#   'Aaron Gordon': 13.4,
#   'Serge Ibaka': 11.9,
#   'LaMarcus Aldridge': 16.3,
#   'DeAndre Jordan': 6.5,
#   'Kawhi Leonard': 18.8,
#   'Rudy Gobert': 8.8,
#   'Nicolas Batum': 7.5,
#   'Harrison Barnes': 13.3,
#   'Marc Gasol': 11.0,
#   'Giannis Antetokounmpo': 17.3,
#   'Steven Adams': 10.1,
#   'Nikola Jokic': 15.1,
#   'Hassan Whiteside': 9.4,
#   'Bradley Beal': 19.6,
#   'Andrew Wiggins': 16.6,
#   'Joel Embiid': 18.7,
#   'CJ McCollum': 17.8,
#   'Jrue Holiday': 17.3,
#   'DeMar DeRozan': 17.1,
#   'Damian Lillard': 19.2,
#   'Al Horford': 10.6,
#   'Paul Millsap': 9.5,
#   'Kevin Durant': 17.7,
#   'James Harden': 24.5,
#   'Mike Conley': 16.0,
#   'Paul George': 21.0,
#   'Kyle Lowry': 11.4,
#   'Gordon Hayward': 8.8,
#   'Blake Griffin': 17.9,
#   'Chris Paul': 12.4,
#   'Russell Westbrook': 20.2,
#   'Stephen Curry': 19.4},
#  'FG%': {'Jimmy Butler': 46.2,
#   'Danilo Gallinari': 46.3,
#   'Aaron Gordon': 44.9,
#   'Serge Ibaka': 52.9,
#   'LaMarcus Aldridge': 51.9,
#   'DeAndre Jordan': 64.1,
#   'Kawhi Leonard': 49.6,
#   'Rudy Gobert': 66.9,
#   'Nicolas Batum': 45.0,
#   'Harrison Barnes': 42.0,
#   'Marc Gasol': 44.8,
#   'Giannis Antetokounmpo': 57.8,
#   'Steven Adams': 59.5,
#   'Nikola Jokic': 51.1,
#   'Hassan Whiteside': 57.1,
#   'Bradley Beal': 47.5,
#   'Andrew Wiggins': 41.2,
#   'Joel Embiid': 48.4,
#   'CJ McCollum': 45.9,
#   'Jrue Holiday': 47.2,
#   'DeMar DeRozan': 48.1,
#   'Damian Lillard': 44.4,
#   'Al Horford': 53.5,
#   'Paul Millsap': 48.4,
#   'Kevin Durant': 52.1,
#   'James Harden': 44.2,
#   'Mike Conley': 43.8,
#   'Paul George': 43.8,
#   'Kyle Lowry': 41.1,
#   'Gordon Hayward': 46.6,
#   'Blake Griffin': 46.2,
#   'Chris Paul': 41.9,
#   'Russell Westbrook': 42.8,
#   'Stephen Curry': 47.2},
#  '3PM': {'Jimmy Butler': 1.0,
#   'Danilo Gallinari': 2.4,
#   'Aaron Gordon': 1.6,
#   'Serge Ibaka': 0.7,
#   'LaMarcus Aldridge': 0.1,
#   'DeAndre Jordan': 0.0,
#   'Kawhi Leonard': 1.9,
#   'Rudy Gobert': 0.0,
#   'Nicolas Batum': 1.5,
#   'Harrison Barnes': 2.3,
#   'Marc Gasol': 1.3,
#   'Giannis Antetokounmpo': 0.7,
#   'Steven Adams': 0.0,
#   'Nikola Jokic': 1.0,
#   'Hassan Whiteside': 0.0,
#   'Bradley Beal': 2.5,
#   'Andrew Wiggins': 1.6,
#   'Joel Embiid': 1.2,
#   'CJ McCollum': 2.4,
#   'Jrue Holiday': 1.8,
#   'DeMar DeRozan': 0.1,
#   'Damian Lillard': 3.0,
#   'Al Horford': 1.1,
#   'Paul Millsap': 0.8,
#   'Kevin Durant': 1.8,
#   'James Harden': 4.8,
#   'Mike Conley': 2.2,
#   'Paul George': 3.8,
#   'Kyle Lowry': 2.4,
#   'Gordon Hayward': 1.1,
#   'Blake Griffin': 2.5,
#   'Chris Paul': 2.2,
#   'Russell Westbrook': 1.6,
#   'Stephen Curry': 5.1},
#  '3PA': {'Jimmy Butler': 3.0,
#   'Danilo Gallinari': 5.5,
#   'Aaron Gordon': 4.4,
#   'Serge Ibaka': 2.3,
#   'LaMarcus Aldridge': 0.5,
#   'DeAndre Jordan': 0.0,
#   'Kawhi Leonard': 5.0,
#   'Rudy Gobert': 0.0,
#   'Nicolas Batum': 4.0,
#   'Harrison Barnes': 5.7,
#   'Marc Gasol': 3.5,
#   'Giannis Antetokounmpo': 2.8,
#   'Steven Adams': 0.0,
#   'Nikola Jokic': 3.4,
#   'Hassan Whiteside': 0.2,
#   'Bradley Beal': 7.3,
#   'Andrew Wiggins': 4.8,
#   'Joel Embiid': 4.1,
#   'CJ McCollum': 6.4,
#   'Jrue Holiday': 5.4,
#   'DeMar DeRozan': 0.6,
#   'Damian Lillard': 8.0,
#   'Al Horford': 3.0,
#   'Paul Millsap': 2.3,
#   'Kevin Durant': 5.0,
#   'James Harden': 13.2,
#   'Mike Conley': 6.1,
#   'Paul George': 9.8,
#   'Kyle Lowry': 7.0,
#   'Gordon Hayward': 3.2,
#   'Blake Griffin': 7.0,
#   'Chris Paul': 6.1,
#   'Russell Westbrook': 5.6,
#   'Stephen Curry': 11.7},
#  '3P%': {'Jimmy Butler': 34.7,
#   'Danilo Gallinari': 43.3,
#   'Aaron Gordon': 34.9,
#   'Serge Ibaka': 29.0,
#   'LaMarcus Aldridge': 23.8,
#   'DeAndre Jordan': 0.0,
#   'Kawhi Leonard': 37.1,
#   'Rudy Gobert': 0.0,
#   'Nicolas Batum': 38.9,
#   'Harrison Barnes': 39.5,
#   'Marc Gasol': 36.3,
#   'Giannis Antetokounmpo': 25.6,
#   'Steven Adams': 0.0,
#   'Nikola Jokic': 30.7,
#   'Hassan Whiteside': 12.5,
#   'Bradley Beal': 35.1,
#   'Andrew Wiggins': 33.9,
#   'Joel Embiid': 30.0,
#   'CJ McCollum': 37.5,
#   'Jrue Holiday': 32.5,
#   'DeMar DeRozan': 15.6,
#   'Damian Lillard': 36.9,
#   'Al Horford': 36.0,
#   'Paul Millsap': 36.5,
#   'Kevin Durant': 35.3,
#   'James Harden': 36.8,
#   'Mike Conley': 36.4,
#   'Paul George': 38.6,
#   'Kyle Lowry': 34.7,
#   'Gordon Hayward': 33.3,
#   'Blake Griffin': 36.2,
#   'Chris Paul': 35.8,
#   'Russell Westbrook': 29.0,
#   'Stephen Curry': 43.7},
#  'FTM': {'Jimmy Butler': 4.8,
#   'Danilo Gallinari': 5.4,
#   'Aaron Gordon': 2.4,
#   'Serge Ibaka': 1.8,
#   'LaMarcus Aldridge': 4.3,
#   'DeAndre Jordan': 2.7,
#   'Kawhi Leonard': 6.1,
#   'Rudy Gobert': 4.1,
#   'Nicolas Batum': 1.0,
#   'Harrison Barnes': 3.0,
#   'Marc Gasol': 2.4,
#   'Giannis Antetokounmpo': 6.9,
#   'Steven Adams': 1.8,
#   'Nikola Jokic': 3.6,
#   'Hassan Whiteside': 1.5,
#   'Bradley Beal': 4.4,
#   'Andrew Wiggins': 2.8,
#   'Joel Embiid': 8.2,
#   'CJ McCollum': 2.3,
#   'Jrue Holiday': 3.1,
#   'DeMar DeRozan': 4.8,
#   'Damian Lillard': 5.9,
#   'Al Horford': 1.1,
#   'Paul Millsap': 2.6,
#   'Kevin Durant': 5.7,
#   'James Harden': 9.7,
#   'Mike Conley': 4.9,
#   'Paul George': 5.9,
#   'Kyle Lowry': 2.5,
#   'Gordon Hayward': 2.2,
#   'Blake Griffin': 5.5,
#   'Chris Paul': 3.0,
#   'Russell Westbrook': 4.1,
#   'Stephen Curry': 3.8},
#  'FTA': {'Jimmy Butler': 5.6,
#   'Danilo Gallinari': 6.0,
#   'Aaron Gordon': 3.2,
#   'Serge Ibaka': 2.4,
#   'LaMarcus Aldridge': 5.1,
#   'DeAndre Jordan': 3.8,
#   'Kawhi Leonard': 7.1,
#   'Rudy Gobert': 6.4,
#   'Nicolas Batum': 1.2,
#   'Harrison Barnes': 3.6,
#   'Marc Gasol': 3.2,
#   'Giannis Antetokounmpo': 9.5,
#   'Steven Adams': 3.7,
#   'Nikola Jokic': 4.4,
#   'Hassan Whiteside': 3.4,
#   'Bradley Beal': 5.5,
#   'Andrew Wiggins': 4.1,
#   'Joel Embiid': 10.1,
#   'CJ McCollum': 2.7,
#   'Jrue Holiday': 4.0,
#   'DeMar DeRozan': 5.7,
#   'Damian Lillard': 6.4,
#   'Al Horford': 1.4,
#   'Paul Millsap': 3.6,
#   'Kevin Durant': 6.5,
#   'James Harden': 11.0,
#   'Mike Conley': 5.8,
#   'Paul George': 7.0,
#   'Kyle Lowry': 3.0,
#   'Gordon Hayward': 2.6,
#   'Blake Griffin': 7.3,
#   'Chris Paul': 3.5,
#   'Russell Westbrook': 6.2,
#   'Stephen Curry': 4.2},
#  'FT%': {'Jimmy Butler': 85.5,
#   'Danilo Gallinari': 90.4,
#   'Aaron Gordon': 73.1,
#   'Serge Ibaka': 76.3,
#   'LaMarcus Aldridge': 84.7,
#   'DeAndre Jordan': 70.5,
#   'Kawhi Leonard': 85.4,
#   'Rudy Gobert': 63.6,
#   'Nicolas Batum': 86.5,
#   'Harrison Barnes': 82.4,
#   'Marc Gasol': 75.9,
#   'Giannis Antetokounmpo': 72.9,
#   'Steven Adams': 50.0,
#   'Nikola Jokic': 82.1,
#   'Hassan Whiteside': 44.9,
#   'Bradley Beal': 80.8,
#   'Andrew Wiggins': 69.9,
#   'Joel Embiid': 80.4,
#   'CJ McCollum': 82.8,
#   'Jrue Holiday': 76.8,
#   'DeMar DeRozan': 83.0,
#   'Damian Lillard': 91.2,
#   'Al Horford': 82.1,
#   'Paul Millsap': 72.7,
#   'Kevin Durant': 88.5,
#   'James Harden': 87.9,
#   'Mike Conley': 84.5,
#   'Paul George': 83.9,
#   'Kyle Lowry': 83.0,
#   'Gordon Hayward': 83.4,
#   'Blake Griffin': 75.3,
#   'Chris Paul': 86.2,
#   'Russell Westbrook': 65.6,
#   'Stephen Curry': 91.6},
#  'OREB': {'Jimmy Butler': 1.9,
#   'Danilo Gallinari': 0.8,
#   'Aaron Gordon': 1.7,
#   'Serge Ibaka': 2.1,
#   'LaMarcus Aldridge': 3.1,
#   'DeAndre Jordan': 3.3,
#   'Kawhi Leonard': 1.3,
#   'Rudy Gobert': 3.8,
#   'Nicolas Batum': 0.9,
#   'Harrison Barnes': 0.7,
#   'Marc Gasol': 1.0,
#   'Giannis Antetokounmpo': 2.2,
#   'Steven Adams': 4.9,
#   'Nikola Jokic': 2.9,
#   'Hassan Whiteside': 3.6,
#   'Bradley Beal': 1.1,
#   'Andrew Wiggins': 1.1,
#   'Joel Embiid': 2.5,
#   'CJ McCollum': 0.9,
#   'Jrue Holiday': 1.1,
#   'DeMar DeRozan': 0.7,
#   'Damian Lillard': 0.9,
#   'Al Horford': 1.8,
#   'Paul Millsap': 2.2,
#   'Kevin Durant': 0.4,
#   'James Harden': 0.8,
#   'Mike Conley': 0.6,
#   'Paul George': 1.4,
#   'Kyle Lowry': 0.6,
#   'Gordon Hayward': 0.7,
#   'Blake Griffin': 1.3,
#   'Chris Paul': 0.6,
#   'Russell Westbrook': 1.5,
#   'Stephen Curry': 0.7},
#  'DREB': {'Jimmy Butler': 3.4,
#   'Danilo Gallinari': 5.3,
#   'Aaron Gordon': 5.7,
#   'Serge Ibaka': 6.0,
#   'LaMarcus Aldridge': 6.1,
#   'DeAndre Jordan': 9.8,
#   'Kawhi Leonard': 6.0,
#   'Rudy Gobert': 9.0,
#   'Nicolas Batum': 4.3,
#   'Harrison Barnes': 3.9,
#   'Marc Gasol': 6.9,
#   'Giannis Antetokounmpo': 10.3,
#   'Steven Adams': 4.6,
#   'Nikola Jokic': 8.0,
#   'Hassan Whiteside': 7.8,
#   'Bradley Beal': 3.9,
#   'Andrew Wiggins': 3.7,
#   'Joel Embiid': 11.1,
#   'CJ McCollum': 3.1,
#   'Jrue Holiday': 3.9,
#   'DeMar DeRozan': 5.3,
#   'Damian Lillard': 3.8,
#   'Al Horford': 5.0,
#   'Paul Millsap': 5.0,
#   'Kevin Durant': 5.9,
#   'James Harden': 5.8,
#   'Mike Conley': 2.8,
#   'Paul George': 6.8,
#   'Kyle Lowry': 4.2,
#   'Gordon Hayward': 3.8,
#   'Blake Griffin': 6.2,
#   'Chris Paul': 3.9,
#   'Russell Westbrook': 9.6,
#   'Stephen Curry': 4.7},
#  'REB': {'Jimmy Butler': 5.3,
#   'Danilo Gallinari': 6.1,
#   'Aaron Gordon': 7.4,
#   'Serge Ibaka': 8.1,
#   'LaMarcus Aldridge': 9.2,
#   'DeAndre Jordan': 13.1,
#   'Kawhi Leonard': 7.3,
#   'Rudy Gobert': 12.9,
#   'Nicolas Batum': 5.2,
#   'Harrison Barnes': 4.7,
#   'Marc Gasol': 7.9,
#   'Giannis Antetokounmpo': 12.5,
#   'Steven Adams': 9.5,
#   'Nikola Jokic': 10.8,
#   'Hassan Whiteside': 11.3,
#   'Bradley Beal': 5.0,
#   'Andrew Wiggins': 4.8,
#   'Joel Embiid': 13.6,
#   'CJ McCollum': 4.0,
#   'Jrue Holiday': 5.0,
#   'DeMar DeRozan': 6.0,
#   'Damian Lillard': 4.6,
#   'Al Horford': 6.7,
#   'Paul Millsap': 7.2,
#   'Kevin Durant': 6.4,
#   'James Harden': 6.6,
#   'Mike Conley': 3.4,
#   'Paul George': 8.2,
#   'Kyle Lowry': 4.8,
#   'Gordon Hayward': 4.5,
#   'Blake Griffin': 7.5,
#   'Chris Paul': 4.6,
#   'Russell Westbrook': 11.1,
#   'Stephen Curry': 5.3},
#  'AST': {'Jimmy Butler': 4.0,
#   'Danilo Gallinari': 2.6,
#   'Aaron Gordon': 3.7,
#   'Serge Ibaka': 1.3,
#   'LaMarcus Aldridge': 2.4,
#   'DeAndre Jordan': 2.3,
#   'Kawhi Leonard': 3.3,
#   'Rudy Gobert': 2.0,
#   'Nicolas Batum': 3.3,
#   'Harrison Barnes': 1.5,
#   'Marc Gasol': 4.4,
#   'Giannis Antetokounmpo': 5.9,
#   'Steven Adams': 1.6,
#   'Nikola Jokic': 7.3,
#   'Hassan Whiteside': 0.8,
#   'Bradley Beal': 5.5,
#   'Andrew Wiggins': 2.5,
#   'Joel Embiid': 3.7,
#   'CJ McCollum': 3.0,
#   'Jrue Holiday': 7.7,
#   'DeMar DeRozan': 6.2,
#   'Damian Lillard': 6.9,
#   'Al Horford': 4.2,
#   'Paul Millsap': 2.0,
#   'Kevin Durant': 5.9,
#   'James Harden': 7.5,
#   'Mike Conley': 6.4,
#   'Paul George': 4.1,
#   'Kyle Lowry': 8.7,
#   'Gordon Hayward': 3.4,
#   'Blake Griffin': 5.4,
#   'Chris Paul': 8.2,
#   'Russell Westbrook': 10.7,
#   'Stephen Curry': 5.2},
#  'STL': {'Jimmy Butler': 1.9,
#   'Danilo Gallinari': 0.7,
#   'Aaron Gordon': 0.7,
#   'Serge Ibaka': 0.4,
#   'LaMarcus Aldridge': 0.5,
#   'DeAndre Jordan': 0.6,
#   'Kawhi Leonard': 1.8,
#   'Rudy Gobert': 0.8,
#   'Nicolas Batum': 0.9,
#   'Harrison Barnes': 0.6,
#   'Marc Gasol': 1.1,
#   'Giannis Antetokounmpo': 1.3,
#   'Steven Adams': 1.5,
#   'Nikola Jokic': 1.4,
#   'Hassan Whiteside': 0.6,
#   'Bradley Beal': 1.5,
#   'Andrew Wiggins': 1.0,
#   'Joel Embiid': 0.7,
#   'CJ McCollum': 0.8,
#   'Jrue Holiday': 1.6,
#   'DeMar DeRozan': 1.1,
#   'Damian Lillard': 1.1,
#   'Al Horford': 0.9,
#   'Paul Millsap': 1.2,
#   'Kevin Durant': 0.7,
#   'James Harden': 2.0,
#   'Mike Conley': 1.3,
#   'Paul George': 2.2,
#   'Kyle Lowry': 1.4,
#   'Gordon Hayward': 0.9,
#   'Blake Griffin': 0.7,
#   'Chris Paul': 2.0,
#   'Russell Westbrook': 1.9,
#   'Stephen Curry': 1.3},
#  'BLK': {'Jimmy Butler': 0.6,
#   'Danilo Gallinari': 0.3,
#   'Aaron Gordon': 0.7,
#   'Serge Ibaka': 1.4,
#   'LaMarcus Aldridge': 1.3,
#   'DeAndre Jordan': 1.1,
#   'Kawhi Leonard': 0.4,
#   'Rudy Gobert': 2.3,
#   'Nicolas Batum': 0.6,
#   'Harrison Barnes': 0.2,
#   'Marc Gasol': 1.1,
#   'Giannis Antetokounmpo': 1.5,
#   'Steven Adams': 1.0,
#   'Nikola Jokic': 0.7,
#   'Hassan Whiteside': 1.9,
#   'Bradley Beal': 0.7,
#   'Andrew Wiggins': 0.7,
#   'Joel Embiid': 1.9,
#   'CJ McCollum': 0.4,
#   'Jrue Holiday': 0.8,
#   'DeMar DeRozan': 0.5,
#   'Damian Lillard': 0.4,
#   'Al Horford': 1.3,
#   'Paul Millsap': 0.8,
#   'Kevin Durant': 1.1,
#   'James Harden': 0.7,
#   'Mike Conley': 0.3,
#   'Paul George': 0.4,
#   'Kyle Lowry': 0.5,
#   'Gordon Hayward': 0.3,
#   'Blake Griffin': 0.4,
#   'Chris Paul': 0.3,
#   'Russell Westbrook': 0.5,
#   'Stephen Curry': 0.4},
#  'TOV': {'Jimmy Butler': 1.5,
#   'Danilo Gallinari': 1.5,
#   'Aaron Gordon': 2.1,
#   'Serge Ibaka': 1.5,
#   'LaMarcus Aldridge': 1.8,
#   'DeAndre Jordan': 2.2,
#   'Kawhi Leonard': 2.0,
#   'Rudy Gobert': 1.6,
#   'Nicolas Batum': 1.6,
#   'Harrison Barnes': 1.3,
#   'Marc Gasol': 2.0,
#   'Giannis Antetokounmpo': 3.7,
#   'Steven Adams': 1.7,
#   'Nikola Jokic': 3.1,
#   'Hassan Whiteside': 1.3,
#   'Bradley Beal': 2.7,
#   'Andrew Wiggins': 1.9,
#   'Joel Embiid': 3.5,
#   'CJ McCollum': 1.5,
#   'Jrue Holiday': 3.1,
#   'DeMar DeRozan': 2.6,
#   'Damian Lillard': 2.7,
#   'Al Horford': 1.5,
#   'Paul Millsap': 1.4,
#   'Kevin Durant': 2.9,
#   'James Harden': 5.0,
#   'Mike Conley': 1.9,
#   'Paul George': 2.7,
#   'Kyle Lowry': 2.8,
#   'Gordon Hayward': 1.5,
#   'Blake Griffin': 3.4,
#   'Chris Paul': 2.6,
#   'Russell Westbrook': 4.5,
#   'Stephen Curry': 2.8},
#  'EFF': {'Jimmy Butler': 20.7,
#   'Danilo Gallinari': 20.6,
#   'Aaron Gordon': 18.2,
#   'Serge Ibaka': 18.6,
#   'LaMarcus Aldridge': 24.4,
#   'DeAndre Jordan': 22.3,
#   'Kawhi Leonard': 26.9,
#   'Rudy Gobert': 27.0,
#   'Nicolas Batum': 13.5,
#   'Harrison Barnes': 13.8,
#   'Marc Gasol': 19.3,
#   'Giannis Antetokounmpo': 35.3,
#   'Steven Adams': 19.7,
#   'Nikola Jokic': 28.9,
#   'Hassan Whiteside': 19.7,
#   'Bradley Beal': 24.2,
#   'Andrew Wiggins': 14.2,
#   'Joel Embiid': 32.2,
#   'CJ McCollum': 17.6,
#   'Jrue Holiday': 23.1,
#   'DeMar DeRozan': 22.6,
#   'Damian Lillard': 25.0,
#   'Al Horford': 19.9,
#   'Paul Millsap': 16.6,
#   'Kevin Durant': 27.9,
#   'James Harden': 33.1,
#   'Mike Conley': 20.8,
#   'Paul George': 27.4,
#   'Kyle Lowry': 19.6,
#   'Gordon Hayward': 13.9,
#   'Blake Griffin': 23.7,
#   'Chris Paul': 20.3,
#   'Russell Westbrook': 29.0,
#   'Stephen Curry': 26.1}}

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
db = client.nba_player_analysis_db
collection = db.salary
collection.insert_one(data_dict)

# %%
merged_nba_analysis_df = merged_nba_analysis_df.reset_index()
merged_nba_analysis_df.head()
# Out:
#                 Name       Salary    GP   MIN   PTS  FGM   FGA   FG%  3PM  \
# 0       Jimmy Butler  $20,445,779  65.0  33.6  18.7  6.4  13.9  46.2  1.0
# 1   Danilo Gallinari  $21,587,579  68.0  30.3  19.8  6.0  13.0  46.3  2.4
# 2       Aaron Gordon  $21,590,909  78.0  33.8  16.0  6.0  13.4  44.9  1.6
# 3        Serge Ibaka  $21,666,667  74.0  27.2  15.0  6.3  11.9  52.9  0.7
# 4  LaMarcus Aldridge  $22,347,015  81.0  33.2  21.3  8.4  16.3  51.9  0.1
#
#    3PA  ...   FTA   FT%  OREB  DREB  REB  AST  STL  BLK  TOV   EFF
# 0  3.0  ...   5.6  85.5   1.9   3.4  5.3  4.0  1.9  0.6  1.5  20.7
# 1  5.5  ...   6.0  90.4   0.8   5.3  6.1  2.6  0.7  0.3  1.5  20.6
# 2  4.4  ...   3.2  73.1   1.7   5.7  7.4  3.7  0.7  0.7  2.1  18.2
# 3  2.3  ...   2.4  76.3   2.1   6.0  8.1  1.3  0.4  1.4  1.5  18.6
# 4  0.5  ...   5.1  84.7   3.1   6.1  9.2  2.4  0.5  1.3  1.8  24.4
#
# [5 rows x 22 columns]

# %% [markdown]
# # - Visuals

# %%
data = [go.Scatter(x = merged_nba_analysis_df['Salary'], y = merged_nba_analysis_df['PTS'], text = merged_nba_analysis_df['Name'], hoverinfo = 'text', marker = dict(color='darkblue'), mode = 'markers', name = 'markers', showlegend = False)]
layout = go.Layout(title='Points Per Game vs Salary of top NBA Players',xaxis=dict(title='Salary in Millions', titlefont=dict(size = 14)),yaxis=dict(title='Points Per Game', titlefont=dict(size = 14)))
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='add-hover-text')
# Out:
# C:\Users\rossk\Anaconda3\lib\site-packages\IPython\core\display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~KeithRoss/2.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ### - NBA Efficiency, invented by Martin Manley, is being considered the first ever player evaluation metric which indicates player’s linear efficiency.
# ### - NBA Efficiency Formula= (Points)+(Rebounds)+(Steals)+(Assists)+(Blocked Shots)-(Turnovers)-(Missed Shots/Games Played

# %%
data1 = [go.Scatter(x = merged_nba_analysis_df['Salary'], y = merged_nba_analysis_df['EFF'], text = merged_nba_analysis_df['Name'], hoverinfo = 'text', marker = dict(color='darkblue'), mode = 'markers', name = 'markers', showlegend = False)]
layout1 = go.Layout(title='Effeciency vs Salary of top NBA Players',xaxis=dict(title='Salary in Millions', titlefont=dict(size = 14)),yaxis=dict(title='Effeciency Rating', titlefont=dict(size = 14)))
fig1 = go.Figure(data=data1, layout=layout1)
py.iplot(fig1, filename='add-hover-text')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~KeithRoss/2.embed" height="525px" width="100%"></iframe>
